# %%
from alerts.alert_manager import send_alert

send_alert("Test alert from Jupyter", severity="low")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from data.unified_loader import load_all

df = load_all()

sns.boxplot(x="label", y="amount", data=df)
plt.title("Fraud Amount Distribution")
